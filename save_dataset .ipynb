# %%
# !zip -r Finalproject.zip Finalproject/
# Out:
# 	zip warning: name not matched: Finalproject/
#
# zip error: Nothing to do! (try: zip -r Finalproject.zip . -i Finalproject/)

# %%
# !ls -ld Finalproject
# Out:
# ls: cannot access 'Finalproject': No such file or directory
